# %% [markdown]
# <a href="https://colab.research.google.com/github/kang-min-suh/Big_Data_ML/blob/main/3_5%EB%B9%85%EB%B6%84%EA%B8%B0%EC%8B%A4%EA%B8%B0_%EC%9D%B8%ED%94%84%EB%9F%B0_%EC%9E%91%EC%97%85%ED%98%952_%EB%AA%A8%EB%8D%B8%EB%A7%81_%EB%B0%8F_%ED%8F%89%EA%B0%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 데이터 : data_atype.zip (수업노트에서 다운로드)
#
# ## 머신러닝
# - 문제정의, 라이브러리/데이터 불러오기
# - 탐색적 데이터 분석 (EDA)
# - 데이터 전처리
# - 피처엔지니어링
# - (Train/Validation 나누기)
# - 모델 선택/훈련/평가/최적화
# - 예측
# - (csv 생성)

# %% [markdown]
# ## 1. 베이스라인
# - 문제정의, 라이브러리 및 데이터 불러오기
# - 데이터 전처리 (단순 일괄 처리)
# - 모델 선택, 훈련
# - 평가
#
# ## 2. 베이스라인
# - 훈련/검증용 데이터 분리
# - 모델 선택, 훈련
#     - 의사결정나무
#     - 랜덤포레스트
#     - XGBoost
# - 평가

# %% [markdown]
# ## 문제1
# - "<= 50K -> 0"
# - "> 50K -> 1"
# - 평가: 정확도

# %%
# 라이브러리 및 데이터 불러오기
# import pandas as pd
# X_train = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/main/p2/data_atype_y/X_train.csv")
# X_test = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/main/p2/data_atype_y/X_test.csv")
# y_train = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/main/p2/data_atype_y/y_train.csv")
# X_train = pd.read_csv("X_train.csv")
# X_test = pd.read_csv("X_test.csv")
# y_train = pd.read_csv("y_train.csv")

import pandas as pd
X_train = pd.read_csv('X_train.csv')
y_train = pd.read_csv('y_train.csv')
X_test = pd.read_csv('X_test.csv')

# %%
# 데이터 크기
# X_train.shape, X_test.shape, y_train.shape

X_train.shape, X_test.shape, y_train.shape
# Out:
# ((29304, 15), (3257, 15), (29304, 2))

# %%
# 데이터 샘플
# X_train.head()

X_train.head()
# Out:
#       id   age  workclass  fnlwgt     education  education.num  \
# 0   3331  34.0  State-gov  177331  Some-college             10
# 1  19749  58.0    Private  290661       HS-grad              9
# 2   1157  48.0    Private  125933  Some-college             10
# 3    693  58.0    Private  100313  Some-college             10
# 4  12522  41.0    Private  195661  Some-college             10
#
#        marital.status        occupation relationship   race     sex  \
# 0  Married-civ-spouse    Prof-specialty      Husband  Black    Male
# 1  Married-civ-spouse      Craft-repair      Husband  White    Male
# 2             Widowed   Exec-managerial    Unmarried  Black  Female
# 3  Married-civ-spouse   Protective-serv      Husband  White    Male
# 4  Married-civ-spouse  Transport-moving      Husband  White    Male
#
#    capital.gain  capital.loss  hours.per.week native.country
# 0          4386             0            40.0  United-States
# ...

# %%
# 타겟 수 확인
# y_train['income'].value_counts()
# y_train['income'].value_counts()
# y_train.head() # 먼저 타겟확인후, 타겟 컬럼명을 넣고 밸류 카운츠!!!
y_train['income'].value_counts()
# Out:
# income
# <=50K    22263
# >50K      7041
# Name: count, dtype: int64

# %%
# type확인
# X_train.info()
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29304 entries, 0 to 29303
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              29304 non-null  int64
#  1   age             29292 non-null  float64
#  2   workclass       27642 non-null  object
#  3   fnlwgt          29304 non-null  int64
#  4   education       29304 non-null  object
#  5   education.num   29304 non-null  int64
#  6   marital.status  29304 non-null  object
#  7   occupation      27636 non-null  object
#  8   relationship    29304 non-null  object
#  9   race            29304 non-null  object
#  10  sex             29304 non-null  object
#  11  capital.gain    29304 non-null  int64
#  12  capital.loss    29304 non-null  int64
#  13  hours.per.week  29291 non-null  float64
#  14  native.country  28767 non-null  object
# dtypes: float64(2), int64(5), object(8)
# memory usage: 3.4+ MB

# %%
# 수치형 데이터
# cols =[
#        'age',
#        'fnlwgt',
#        'education.num',
#        'capital.gain',
#        'capital.loss',
#        'hours.per.week'
# ]

cols = [
    'age',
    'fnlwgt',
    'education.num',
    'capital.gain',
    'capital.loss',
    'hours.per.week'
]

# %%
# 수치형 데이처 통계
# X_train[cols].describe()
X_train[cols].describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  29292.000000  2.930400e+04   29304.000000  29304.000000  29304.000000
# mean      38.553223  1.897488e+05      10.080842   1093.858722     86.744506
# std       13.628811  1.055250e+05       2.570824   7477.435640    401.518928
# min      -38.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.177890e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783765e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370682e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    29291.000000
# mean        40.434229
# std         12.324036
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# 결측값
# X_train[cols].isnull().sum()
X_train[cols].isnull().sum()
# Out:
# age               12
# fnlwgt             0
# education.num      0
# capital.gain       0
# capital.loss       0
# hours.per.week    13
# dtype: int64

# %%
# 간단한 결측치 처리
# X_train = X_train.fillna(0)
# X_test = X_test.fillna(0)

X_train = X_train.fillna(0) # 결측치는 train과 test 함께 처리한다!!!
X_test = X_test.fillna(0)

# %%
# 결측치 확인
# X_train[cols].isnull().sum()
X_train[cols].isnull().sum()
# Out:
# age               0
# fnlwgt            0
# education.num     0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# dtype: int64

# %%
y_train # 문자형 (>50K, <=50K)로 되어 있는거 숫자로 변경하기
# Out:
#           id income
# 0       3331   >50K
# 1      19749  <=50K
# 2       1157  <=50K
# 3        693   >50K
# 4      12522  <=50K
# ...      ...    ...
# 29299  15999  <=50K
# 29300  21604  <=50K
# 29301  26839  <=50K
# 29302  16681  <=50K
# 29303  16069  <=50K
#
# [29304 rows x 2 columns]

# %%
# 베이스 라인에서는 그외 전처리 및 피처 엔지니어링 생략

# %%
# target값 변경
# <=50K -> 0
# >50K -> 1
# y = (X_train['income'] != '<=50K').astype(int)

# %%
# y = (y_train['income'] == '>50K').astype(int)
# y[:3]

y = (y_train['income'] == '>50K').astype(int)  # int형으로 바꾸는 방법. 전체 괄호로 묶어서 astype(int)
y[:3]
# Out:
# 0    1
# 1    0
# 2    0
# Name: income, dtype: int64

# %%
# X_train[cols]
X_train[cols]
# Out:
#         age  fnlwgt  education.num  capital.gain  capital.loss  hours.per.week
# 0      34.0  177331             10          4386             0            40.0
# 1      58.0  290661              9             0             0            40.0
# 2      48.0  125933             10             0          1669            38.0
# 3      58.0  100313             10             0          1902            40.0
# 4      41.0  195661             10             0             0            54.0
# ...     ...     ...            ...           ...           ...             ...
# 29299  28.0   47168              6             0             0            40.0
# 29300  44.0  231793             16             0             0            38.0
# 29301  41.0  201435              9             0             0            40.0
# 29302  43.0  137722              9             0             0            40.0
# 29303  22.0  406978             13             0             0            40.0
#
# ...

# %% [markdown]
# ## 머신러닝 모델

# %%
# 랜덤포레스트
# from sklearn.ensemble import RandomForestClassifier
# rf = RandomForestClassifier()
# rf.fit(X_train[cols], y)
# pred = rf.predict(X_test[cols])

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train[cols],y)
pred = rf.predict(X_test[cols])

# %%
# pred[:10] # 0은 하위소득, 1은 상위소득


submit = pd.DataFrame(   # 시험장에서 csv파일 제출하는 방법 ☆☆☆☆☆☆(이것대로하는 건 아님. 주어진 예시대로 )
    {
        'id': X_test['id'],
        'income': pred
    }
)
submit.to_csv('0000.csv', index = False)

# %%
len(X_test)
# Out:
# 3257

# %%
y_train
# Out:
#           id income
# 0       3331   >50K
# 1      19749  <=50K
# 2       1157  <=50K
# 3        693   >50K
# 4      12522  <=50K
# ...      ...    ...
# 29299  15999  <=50K
# 29300  21604  <=50K
# 29301  26839  <=50K
# 29302  16681  <=50K
# 29303  16069  <=50K
#
# [29304 rows x 2 columns]

# %%
# len(X_test)
pred
# Out:
# 3257

# %%
# 예측 및 csv 파일 생성
# pred[:10]
submit = pd.DataFrame(
            {
                'id':X_test['id'],
                'income':pred
            }
        )
submit.to_csv("11111.csv", index=False)

# %%
y_train.head()
# Out:
#       id income
# 0   3331   >50K
# 1  19749  <=50K
# 2   1157  <=50K
# 3    693   >50K
# 4  12522  <=50K

# %%
# 평가 (수험자는 알 수 없는 부분임) accuracy
# from sklearn.metrics import accuracy_score
# y_test = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/main/p2/data_atype_y/y_test.csv")
# # y_test = pd.read_csv("y_test.csv")
# ans = (y_test['income'] == '>50K').astype(int)  # 오류안나게 변경하는 부분
# accuracy_score(ans, pred)

from sklearn.metrics import accuracy_score  # 실제 클래스 레이블과 예측된 클래스 레이블을 직접 비교하여 정확도를 계산
y_test = pd.read_csv('y_test.csv')
ans = (y_test['income'] == '>50K').astype(int)
accuracy_score(ans,pred)
# Out:
# 0.8151673319005219

# %%
y_test
# Out:
#          id income
# 0     11574  <=50K
# 1     15847  <=50K
# 2     17655  <=50K
# 3     19790   >50K
# 4     31812  <=50K
# ...     ...    ...
# 3252  20589  <=50K
# 3253   5668  <=50K
# 3254  27652  <=50K
# 3255  14735  <=50K
# 3256   4426  <=50K
#
# [3257 rows x 2 columns]

# %% [markdown]
# ## 문제2
# - "<= 50K -> 0"
# - "> 50K -> 1"
# - 평가: roc_auc 예측 해야할 값은 : 확률

# %% [markdown]
# ## 검증용 데이터 분리

# %%
y_train
# Out:
#           id income
# 0       3331   >50K
# 1      19749  <=50K
# 2       1157  <=50K
# 3        693   >50K
# 4      12522  <=50K
# ...      ...    ...
# 29299  15999  <=50K
# 29300  21604  <=50K
# 29301  26839  <=50K
# 29302  16681  <=50K
# 29303  16069  <=50K
#
# [29304 rows x 2 columns]

# %%
# 학습용 데이터와 검증용 데이터로 구분
# from sklearn.model_selection import train_test_split
# y = (y_train['income'] == '>50K').astype(int)
# X_tr, X_val, y_tr, y_val = train_test_split(X_train, y, test_size=0.1, random_state=2022)

from sklearn.model_selection import train_test_split  # 수험장에서 accuracy 작업할 수 없으므로 이 작업이 필요
y = (y_train['income'] == '>50K').astype(int) # y_train 데이터가 문자형이므로 int형으로 변환
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y, test_size = 0.1, random_state = 2022)

# %%
X_tr.shape, X_val.shape, y_tr.shape, y_val.shape
# Out:
# ((26373, 15), (2931, 15), (26373,), (2931,))

# %%
X_tr.shape, X_val.shape, y_tr.shape, y_val.shape
# Out:
# ((26373, 15), (2931, 15), (26373,), (2931,))

# %%
# 의사결정나무
# from sklearn.metrics import roc_auc_score
# from sklearn.tree import DecisionTreeClassifier
# dt = DecisionTreeClassifier()
# dt.fit(X_tr[cols], y_tr)
# pred=dt.predict_proba(X_val[cols])
# roc_auc_score(y_val,pred[:,1])

#from sklearn.metrics import roc_acu_score
from sklearn.tree import DecisionTreeClassifier  # 평가: roc_auc 예측 해야할 값은 : 확률
dt = DecisionTreeClassifier()
dt.fit(X_tr[cols], y_tr)
pred = dt.predict_proba(X_val[cols]) # 확률예측은 proba
#roc_auc_score(y_val, pred[:,1])
roc_auc_score(y_val, pred[:,1])
# Out:
# 0.7017316581812959

# %%
# 랜덤포레스트
# from sklearn.ensemble import RandomForestClassifier
# rf = RandomForestClassifier()
# rf.fit(X_tr[cols], y_tr)
# pred=rf.predict_proba(X_val[cols])
# roc_auc_score(y_val,pred[:,1])

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_tr[cols], y_tr)
pred = rf.predict_proba(X_val[cols])
roc_auc_score(y_val, pred[:,1])
# Out:
# 0.8497796449373142

# %%
# XGBoost
# from xgboost import XGBClassifier
# xgb = XGBClassifier()
# xgb.fit(X_tr[cols], y_tr)
# pred=xgb.predict_proba(X_val[cols])
# pred[:,1]

from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(X_tr[cols], y_tr)
pred = xgb.predict_proba(X_val[cols])
pred[:,1]  # 컬럼 선택 (일일 확률 )
roc_auc_score(y_val, pred[:,1])  # 자체평가 --> 가장 높으므로 이것으로 csv파일을 만들면 됨.
# Out:
# 0.8859038904196574

# %%
print(pred[:,1])
# Out:
# [0.33148018 0.1789185  0.26204547 ... 0.03034037 0.09246464 0.02522616]

# %%
y_train
# Out:
#           id income
# 0       3331   >50K
# 1      19749  <=50K
# 2       1157  <=50K
# 3        693   >50K
# 4      12522  <=50K
# ...      ...    ...
# 29299  15999  <=50K
# 29300  21604  <=50K
# 29301  26839  <=50K
# 29302  16681  <=50K
# 29303  16069  <=50K
#
# [29304 rows x 2 columns]

# %%
# 평가 데이터로 예측 및 csv파일 생성
# from sklearn.metrics import roc_auc_score
# roc_auc_score(y_val,pred[:,1])

# pred=xgb.predict_proba(X_test[cols])
# submit = pd.DataFrame(
#             {
#                 'id':X_test['id'],
#                 'income':pred[:,1]
#             }
#         )
# submit.to_csv("22222.csv", index=False)

from sklearn.metrics import roc_auc_score  # 실제 클래스 레이블과 예측 확률을 비교하여 모델의 성능을 평가. 얼마나 확신을 가지고 예측했는지
# 이진 분류문제에서 사용되며, 양성 클래스(positive class)에 대한 예측 확률을 기반으로 계산
# 문제에서는 >50K인 경우를 양성 클래스로, <=50K인 경우를 음성 클래스로 정의
# 따라서, ans에서 !='<=50K'는 양성
# pred[:, 1]은 모든 행의 두번째 열(1)을 선택, 두번째 클래스는 >50K에 속할 확률을 가져옴
roc_auc_score(y_val, pred[:,1])

pred = xgb.predict_proba(X_test[cols])
submit = pd.DataFrame(
{
    'id': X_test['id'],
    'income':pred[:,1]
}
)
submit.to_csv('2222.csv', index = False)

# %% [markdown]
# # 평가
# - 수험자는 알 수 없는 영역임

# %%
# from sklearn.metrics import roc_auc_score
# y_test = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/main/p2/data_atype_y/y_test.csv")
# # y_test = pd.read_csv("y_test.csv")
# ans = (y_test['income'] != '<=50K').astype(int)
# roc_auc_score(ans, pred[:,1])

from sklearn.metrics import roc_auc_score
y_test = pd.read_csv('y_test.csv')
ans = (y_test['income'] != '<=50K').astype(int)
roc_auc_score(ans,pred[:,1])
# Out:
# 0.880757783882784
